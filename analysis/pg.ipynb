# %%
import pandas as pd

# %%
df = pd.read_parquet("/net/scratch/zsarwar/hf_cache/train-00000-of-00001.parquet")

# %%
df
# Out:
#                                              instruction  \
# 0      You are a helpful science assistant. Using the...
# 1      You are a helpful science assistant. Using the...
# 2      You are a helpful science assistant. Using the...
# 3      You are a helpful science assistant. Using the...
# 4      You are a helpful science assistant. Using the...
# ...                                                  ...
# 49969  You are a helpful science assistant. Using the...
# 49970  You are a helpful science assistant. Using the...
# 49971  You are a helpful science assistant. Using the...
# 49972  You are a helpful science assistant. Using the...
# 49973  You are a helpful science assistant. Using the...
#
#                                                    input  \
# 0      Question: A random sample of five furniture st...
# 1      Question: How are complex sound waves, contain...
# 2      Question: Find the eigenvectors of the matrix:...
# ...
